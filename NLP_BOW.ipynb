# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/findingfoot/ML_practice-codes/blob/master/NLP_BOW.ipynb)

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import numpy as np
import csv
import string
import requests
import io
from zipfile import ZipFile
from tensorflow.contrib import learn
from tensorflow.python.framework import ops
ops.reset_default_graph()

sess = tf.Session()

# %%
save_file_name = os.path.join('temp','temp_spam_data.csv')

# Create directory if it doesn't exist
if not os.path.exists('temp'):
    os.makedirs('temp')

if os.path.isfile(save_file_name):
    text_data = []
    with open(save_file_name, 'r') as temp_output_file:
        reader = csv.reader(temp_output_file)
        for row in reader:
            text_data.append(row)
else:
    zip_url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00228/smsspamcollection.zip'
    r = requests.get(zip_url)
    z = ZipFile(io.BytesIO(r.content))
    file = z.read('SMSSpamCollection')
    # Format Data
    text_data = file.decode()
    text_data = text_data.encode('ascii',errors='ignore')
    text_data = text_data.decode().split('\n')
    text_data = [x.split('\t') for x in text_data if len(x)>=1]
    
    # And write to csv
    with open(save_file_name, 'w') as temp_output_file:
        writer = csv.writer(temp_output_file)
        writer.writerows(text_data)

texts = [x[1] for x in text_data]
target = [x[0] for x in text_data]

# %%
target = [1 if x=='spam' else 0 for x in target]

# Normalize text
# Lower case
texts = [x.lower() for x in texts]

# Remove punctuation
texts = [''.join(c for c in x if c not in string.punctuation) for x in texts]

# Remove numbers
texts = [''.join(c for c in x if c not in '0123456789') for x in texts]

# Trim extra whitespace
texts = [' '.join(x.split()) for x in texts]

# %%
# %matplotlib inline
# Plot histogram of text lengths
text_lengths = [len(x.split()) for x in texts]
text_lengths = [x for x in text_lengths if x < 50]
plt.hist(text_lengths, bins=25)
plt.title('Histogram of # of Words in Texts')
plt.show()

# %%
sentence_size = 25

#eliminating less frequently occuring words
min_word_frequency = 3

vocab_processor = learn.preprocessing.VocabularyProcessor(sentence_size, 
                                                          min_frequency=min_word_frequency)

vocab_processor.transform(texts)
transformed_texts = np.array([x for x in vocab_processor.transform(texts)])
embedding_size = len(np.unique(transformed_texts))



train_indices = np.random.choice(len(texts), round(len(texts)*0.8), replace=False)
test_indices = np.array(list(set(range(len(texts))) - set(train_indices)))
texts_train = [x for ix, x in enumerate(texts) if ix in train_indices]
texts_test = [x for ix, x in enumerate(texts) if ix in test_indices]
target_train = [x for ix, x in enumerate(target) if ix in train_indices]
target_test = [x for ix, x in enumerate(target) if ix in test_indices]
# Out:
# WARNING:tensorflow:From <ipython-input-5-fde72223d328>:7: VocabularyProcessor.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/preprocessing/text.py:154: CategoricalVocabulary.__init__ (from tensorflow.contrib.learn.python.learn.preprocessing.categorical_vocabulary) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/contrib/learn/python/learn/preprocessing/text.py:203: tokenizer (from tensorflow.contrib.learn.python.learn.preprocessing.text) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tensorflow/transform or tf.data.

# %%
identity_mat = tf.diag(tf.ones(shape=[embedding_size]))

# Create variables for logistic regression
A = tf.Variable(tf.random_normal(shape=[embedding_size,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# Initialize placeholders
x_data = tf.placeholder(shape=[sentence_size], dtype=tf.int32)
y_target = tf.placeholder(shape=[1, 1], dtype=tf.float32)


x_embed = tf.nn.embedding_lookup(identity_mat, x_data)
x_col_sums = tf.reduce_sum(x_embed, 0)

x_col_sums_2D = tf.expand_dims(x_col_sums, 0)
model_output = tf.add(tf.matmul(x_col_sums_2D, A), b)

# %%
loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=model_output, labels=y_target))

# Prediction operation
prediction = tf.sigmoid(model_output)

# Declare optimizer
my_opt = tf.train.GradientDescentOptimizer(0.001)
train_step = my_opt.minimize(loss)

# Intitialize Variables
init = tf.global_variables_initializer()
sess.run(init)

# %%
print('Starting Training Over {} Sentences.'.format(len(texts_train)))
loss_vec = []
train_acc_all = []
train_acc_avg = []
for ix, t in enumerate(vocab_processor.fit_transform(texts_train)):
    y_data = [[target_train[ix]]]
    
    
    sess.run(train_step, feed_dict={x_data: t, y_target: y_data})
    temp_loss = sess.run(loss, feed_dict={x_data: t, y_target: y_data})
    loss_vec.append(temp_loss)
    
    if (ix+1)%10==0:
        print('Training Observation #' + str(ix+1) + ': Loss = ' + str(temp_loss))
        
    # Keep trailing average of past 50 observations accuracy
    # Get prediction of single observation
    [[temp_pred]] = sess.run(prediction, feed_dict={x_data:t, y_target:y_data})
    # Get True/False if prediction is accurate
    train_acc_temp = target_train[ix]==np.round(temp_pred)
    train_acc_all.append(train_acc_temp)
    if len(train_acc_all) >= 50:
        train_acc_avg.append(np.mean(train_acc_all[-50:]))
# Out:
# Starting Training Over 4459 Sentences.
# Training Observation #10: Loss = 7.95562
# Training Observation #20: Loss = 17.846455
# Training Observation #30: Loss = 2.1564586
# Training Observation #40: Loss = 14.257138
# Training Observation #50: Loss = 13.855056
# Training Observation #60: Loss = 13.490976
# Training Observation #70: Loss = 4.3791842
# Training Observation #80: Loss = 4.1548543
# Training Observation #90: Loss = 0.5718265
# Training Observation #100: Loss = 0.004745544
# Training Observation #110: Loss = 3.6940694
# Training Observation #120: Loss = 1.3086423
# Training Observation #130: Loss = 12.071793
# Training Observation #140: Loss = 0.0053393827
# Training Observation #150: Loss = 5.091506
# Training Observation #160: Loss = 0.56255937
# Training Observation #170: Loss = 0.11786534
# Training Observation #180: Loss = 3.2458637
# Training Observation #190: Loss = 0.09201024
# Training Observation #200: Loss = 0.588168
# Training Observation #210: Loss = 0.006603742
# Training Observation #220: Loss = 0.00035544686
# Training Observation #230: Loss = 8.122879
# Training Observation #240: Loss = 0.088188685
# Training Observation #250: Loss = 1.1771691
# Training Observation #260: Loss = 0.00092736026
# Training Observation #270: Loss = 4.6988173
# Training Observation #280: Loss = 0.0005833113
# Training Observation #290: Loss = 7.4006386
# Training Observation #300: Loss = 0.033875246
# Training Observation #310: Loss = 0.0012221809
# Training Observation #320: Loss = 5.9395266
# Training Observation #330: Loss = 0.027850265
# Training Observation #340: Loss = 0.0035182089
# Training Observation #350: Loss = 0.0017134293
# Training Observation #360: Loss = 5.772235e-05
# Training Observation #370: Loss = 0.0059211664
# Training Observation #380: Loss = 0.14753102
# Training Observation #390: Loss = 0.034396563
# Training Observation #400: Loss = 3.4755821
# Training Observation #410: Loss = 5.5154662e-05
# Training Observation #420: Loss = 1.3222498
# Training Observation #430: Loss = 0.0032488557
# Training Observation #440: Loss = 3.6156669e-06
# Training Observation #450: Loss = 7.3276157
# Training Observation #460: Loss = 0.63472086
# Training Observation #470: Loss = 2.5443616e-05
# Training Observation #480: Loss = 0.00033033697
# Training Observation #490: Loss = 0.07190888
# Training Observation #500: Loss = 5.6622022e-05
# Training Observation #510: Loss = 6.752585e-05
# Training Observation #520: Loss = 3.8375962
# Training Observation #530: Loss = 0.011187344
# Training Observation #540: Loss = 3.8320987
# Training Observation #550: Loss = 0.005305554
# Training Observation #560: Loss = 0.00055742636
# Training Observation #570: Loss = 3.360716e-05
# Training Observation #580: Loss = 0.016898768
# Training Observation #590: Loss = 0.0010143983
# Training Observation #600: Loss = 0.0005834075
# Training Observation #610: Loss = 0.00023806521
# Training Observation #620: Loss = 0.109307945
# Training Observation #630: Loss = 3.3987117
# Training Observation #640: Loss = 0.33930454
# Training Observation #650: Loss = 0.99093336
# Training Observation #660: Loss = 0.003008776
# Training Observation #670: Loss = 0.052762676
# Training Observation #680: Loss = 0.046421573
# Training Observation #690: Loss = 2.7728324
# Training Observation #700: Loss = 0.413898
# Training Observation #710: Loss = 4.501805
# Training Observation #720: Loss = 1.32400855e-05
# Training Observation #730: Loss = 0.8976155
# Training Observation #740: Loss = 0.0028419823
# Training Observation #750: Loss = 2.8643455e-05
# Training Observation #760: Loss = 0.05216552
# Training Observation #770: Loss = 0.020295266
# Training Observation #780: Loss = 0.00066243124
# Training Observation #790: Loss = 1.6943115e-05
# Training Observation #800: Loss = 0.010590996
# Training Observation #810: Loss = 1.4550346e-07
# Training Observation #820: Loss = 2.605049e-05
# Training Observation #830: Loss = 0.0003490502
# Training Observation #840: Loss = 0.06986951
# Training Observation #850: Loss = 2.3597097e-05
# Training Observation #860: Loss = 3.3411693e-06
# Training Observation #870: Loss = 11.361621
# Training Observation #880: Loss = 2.8128097e-06
# Training Observation #890: Loss = 0.0013899761
# Training Observation #900: Loss = 1.692596e-07
# Training Observation #910: Loss = 0.00964532
# Training Observation #920: Loss = 0.0011154887
# Training Observation #930: Loss = 0.007876483
# Training Observation #940: Loss = 0.07469433
# Training Observation #950: Loss = 0.7666199
# Training Observation #960: Loss = 3.7900422e-06
# Training Observation #970: Loss = 0.6219113
# Training Observation #980: Loss = 9.523196e-06
# Training Observation #990: Loss = 0.00059671915
# Training Observation #1000: Loss = 0.00078200357
# Training Observation #1010: Loss = 5.9014365e-06
# Training Observation #1020: Loss = 4.842567
# Training Observation #1030: Loss = 0.00020611823
# Training Observation #1040: Loss = 3.9492068e-05
# Training Observation #1050: Loss = 0.0013954818
# Training Observation #1060: Loss = 1.6632324e-05
# Training Observation #1070: Loss = 0.0010863004
# Training Observation #1080: Loss = 0.20778704
# Training Observation #1090: Loss = 2.3224192
# Training Observation #1100: Loss = 0.000591811
# Training Observation #1110: Loss = 4.1949406e-05
# Training Observation #1120: Loss = 0.00034411275
# Training Observation #1130: Loss = 1.368154e-06
# Training Observation #1140: Loss = 0.00013843145
# Training Observation #1150: Loss = 0.016248245
# Training Observation #1160: Loss = 4.0846603e-06
# Training Observation #1170: Loss = 0.0039720493
# Training Observation #1180: Loss = 0.19654118
# Training Observation #1190: Loss = 0.53407747
# Training Observation #1200: Loss = 1.914571
# Training Observation #1210: Loss = 0.0019491698
# Training Observation #1220: Loss = 9.448158e-07
# Training Observation #1230: Loss = 0.00029144503
# Training Observation #1240: Loss = 0.013751169
# Training Observation #1250: Loss = 9.542574e-05
# Training Observation #1260: Loss = 0.00045885437
# Training Observation #1270: Loss = 3.1230444e-05
# Training Observation #1280: Loss = 5.75984
# Training Observation #1290: Loss = 0.13591938
# Training Observation #1300: Loss = 0.00055597344
# Training Observation #1310: Loss = 0.0012336274
# Training Observation #1320: Loss = 5.231307e-07
# Training Observation #1330: Loss = 0.001140782
# Training Observation #1340: Loss = 2.5087402
# Training Observation #1350: Loss = 0.09117584
# Training Observation #1360: Loss = 12.0912285
# Training Observation #1370: Loss = 2.8526913e-06
# Training Observation #1380: Loss = 0.44445625
# Training Observation #1390: Loss = 0.0009501147
# Training Observation #1400: Loss = 5.000606e-05
# Training Observation #1410: Loss = 1.0006431e-05
# Training Observation #1420: Loss = 0.3875023
# Training Observation #1430: Loss = 4.173151e-06
# Training Observation #1440: Loss = 9.473086e-05
# Training Observation #1450: Loss = 0.0024988784
# Training Observation #1460: Loss = 0.012215909
# Training Observation #1470: Loss = 0.00012532588
# Training Observation #1480: Loss = 4.5573797e-06
# Training Observation #1490: Loss = 0.010126836
# Training Observation #1500: Loss = 0.00091329287
# Training Observation #1510: Loss = 0.87365746
# Training Observation #1520: Loss = 0.0007442541
# Training Observation #1530: Loss = 4.445303
# Training Observation #1540: Loss = 1.7200265
# Training Observation #1550: Loss = 0.00030283214
# Training Observation #1560: Loss = 4.593378e-06
# Training Observation #1570: Loss = 4.9293667e-05
# Training Observation #1580: Loss = 0.00086327334
# Training Observation #1590: Loss = 2.0600762
# Training Observation #1600: Loss = 3.1419906e-06
# Training Observation #1610: Loss = 4.86391e-06
# Training Observation #1620: Loss = 1.3198558e-05
# Training Observation #1630: Loss = 0.0007030626
# Training Observation #1640: Loss = 0.011953349
# Training Observation #1650: Loss = 6.368349e-05
# Training Observation #1660: Loss = 5.627245e-05
# Training Observation #1670: Loss = 0.00019518675
# Training Observation #1680: Loss = 4.0010887e-05
# Training Observation #1690: Loss = 1.03855e-05
# Training Observation #1700: Loss = 0.00052914856
# Training Observation #1710: Loss = 0.0006689295
# Training Observation #1720: Loss = 0.0065575973
# Training Observation #1730: Loss = 2.8025463e-06
# Training Observation #1740: Loss = 0.54136026
# Training Observation #1750: Loss = 0.0002617865
# Training Observation #1760: Loss = 2.07112
# Training Observation #1770: Loss = 0.0065212734
# Training Observation #1780: Loss = 1.6841464e-05
# Training Observation #1790: Loss = 3.115542e-05
# Training Observation #1800: Loss = 0.30309606
# Training Observation #1810: Loss = 0.0003853165
# Training Observation #1820: Loss = 4.1914776e-05
# Training Observation #1830: Loss = 4.466187
# Training Observation #1840: Loss = 6.680056e-05
# Training Observation #1850: Loss = 0.71293503
# Training Observation #1860: Loss = 0.22997124
# Training Observation #1870: Loss = 7.83148e-05
# Training Observation #1880: Loss = 0.00041453177
# Training Observation #1890: Loss = 7.974324
# Training Observation #1900: Loss = 0.11294031
# Training Observation #1910: Loss = 0.0024727497
# Training Observation #1920: Loss = 1.1173176e-05
# Training Observation #1930: Loss = 8.0048296e-05
# Training Observation #1940: Loss = 7.186459e-06
# Training Observation #1950: Loss = 5.5014876e-05
# Training Observation #1960: Loss = 1.9767172e-05
# Training Observation #1970: Loss = 4.106185
# Training Observation #1980: Loss = 4.711783e-06
# Training Observation #1990: Loss = 0.11625173
# Training Observation #2000: Loss = 0.0020350318
# Training Observation #2010: Loss = 3.3816661e-06
# Training Observation #2020: Loss = 0.0007326659
# Training Observation #2030: Loss = 2.8545635e-06
# Training Observation #2040: Loss = 0.0001592882
# Training Observation #2050: Loss = 8.495918
# Training Observation #2060: Loss = 3.2813172e-05
# Training Observation #2070: Loss = 7.872526e-06
# Training Observation #2080: Loss = 0.16207182
# Training Observation #2090: Loss = 0.0017802715
# Training Observation #2100: Loss = 0.00015406101
# Training Observation #2110: Loss = 4.5753695e-06
# Training Observation #2120: Loss = 4.789407e-06
# Training Observation #2130: Loss = 2.116428e-06
# Training Observation #2140: Loss = 2.8984294e-05
# Training Observation #2150: Loss = 0.0014347656
# Training Observation #2160: Loss = 8.743365e-06
# Training Observation #2170: Loss = 0.017753083
# Training Observation #2180: Loss = 10.509405
# Training Observation #2190: Loss = 1.5754729e-06
# Training Observation #2200: Loss = 2.9227302
# Training Observation #2210: Loss = 0.00014169634
# Training Observation #2220: Loss = 0.008860174
# Training Observation #2230: Loss = 11.577113
# Training Observation #2240: Loss = 0.0004671432
# Training Observation #2250: Loss = 0.090259835
# Training Observation #2260: Loss = 7.855202e-06
# Training Observation #2270: Loss = 0.0068778065
# Training Observation #2280: Loss = 0.0007243483
# Training Observation #2290: Loss = 0.00014179149
# Training Observation #2300: Loss = 1.2018838
# Training Observation #2310: Loss = 0.025878344
# Training Observation #2320: Loss = 5.083065
# Training Observation #2330: Loss = 6.993033
# Training Observation #2340: Loss = 0.6045136
# Training Observation #2350: Loss = 6.954647e-05
# Training Observation #2360: Loss = 0.00063527614
# Training Observation #2370: Loss = 0.0025123435
# Training Observation #2380: Loss = 0.00041214228
# Training Observation #2390: Loss = 1.1603588
# Training Observation #2400: Loss = 0.00015871006
# Training Observation #2410: Loss = 2.5098134e-06
# Training Observation #2420: Loss = 3.3661756e-05
# Training Observation #2430: Loss = 0.4751494
# Training Observation #2440: Loss = 6.6394587e-06
# Training Observation #2450: Loss = 3.75744e-08
# Training Observation #2460: Loss = 0.0009905954
# Training Observation #2470: Loss = 0.0023972865
# Training Observation #2480: Loss = 0.00018825561
# Training Observation #2490: Loss = 13.960736
# Training Observation #2500: Loss = 0.07540965
# Training Observation #2510: Loss = 9.237843e-06
# Training Observation #2520: Loss = 0.20267066
# Training Observation #2530: Loss = 6.697042e-06
# Training Observation #2540: Loss = 6.9035086e-05
# Training Observation #2550: Loss = 0.365191
# Training Observation #2560: Loss = 3.6471295e-06
# Training Observation #2570: Loss = 0.0007713161
# Training Observation #2580: Loss = 0.029979939
# Training Observation #2590: Loss = 4.2338128e-05
# Training Observation #2600: Loss = 0.0033416054
# Training Observation #2610: Loss = 0.002307696
# Training Observation #2620: Loss = 0.021691967
# Training Observation #2630: Loss = 0.026902737
# Training Observation #2640: Loss = 0.0066456157
# Training Observation #2650: Loss = 0.0029942524
# Training Observation #2660: Loss = 0.00016763226
# Training Observation #2670: Loss = 0.36654997
# Training Observation #2680: Loss = 3.4787924
# Training Observation #2690: Loss = 6.324302e-05
# Training Observation #2700: Loss = 2.5680752e-06
# Training Observation #2710: Loss = 0.1301207
# Training Observation #2720: Loss = 2.856843e-06
# Training Observation #2730: Loss = 6.947853e-07
# Training Observation #2740: Loss = 0.12806326
# Training Observation #2750: Loss = 1.1104424
# Training Observation #2760: Loss = 1.1939001e-06
# Training Observation #2770: Loss = 3.7303011
# Training Observation #2780: Loss = 0.06081331
# Training Observation #2790: Loss = 0.0008657221
# Training Observation #2800: Loss = 0.016072674
# Training Observation #2810: Loss = 4.624184e-06
# Training Observation #2820: Loss = 0.00019963617
# Training Observation #2830: Loss = 0.0016361084
# Training Observation #2840: Loss = 3.9528164e-05
# Training Observation #2850: Loss = 0.0006425918
# Training Observation #2860: Loss = 0.5903658
# Training Observation #2870: Loss = 6.0654197
# Training Observation #2880: Loss = 0.00021991464
# Training Observation #2890: Loss = 0.00031792792
# Training Observation #2900: Loss = 1.7872326e-05
# Training Observation #2910: Loss = 0.0013155376
# Training Observation #2920: Loss = 0.027572483
# Training Observation #2930: Loss = 0.016966553
# Training Observation #2940: Loss = 0.006434422
# Training Observation #2950: Loss = 0.00037460058
# Training Observation #2960: Loss = 5.9393716
# Training Observation #2970: Loss = 1.270672e-06
# Training Observation #2980: Loss = 0.0027500805
# Training Observation #2990: Loss = 1.8098266e-05
# Training Observation #3000: Loss = 8.343354e-05
# Training Observation #3010: Loss = 0.00021293153
# Training Observation #3020: Loss = 5.076289e-06
# Training Observation #3030: Loss = 0.00019305632
# Training Observation #3040: Loss = 0.16175844
# Training Observation #3050: Loss = 1.9570216e-06
# Training Observation #3060: Loss = 1.904509
# Training Observation #3070: Loss = 0.058717526
# Training Observation #3080: Loss = 0.0032260625
# Training Observation #3090: Loss = 2.5099229e-05
# Training Observation #3100: Loss = 0.16798675
# Training Observation #3110: Loss = 0.0005606547
# Training Observation #3120: Loss = 5.925463
# Training Observation #3130: Loss = 1.3558755e-05
# Training Observation #3140: Loss = 2.8831637
# Training Observation #3150: Loss = 0.021401815
# Training Observation #3160: Loss = 0.07134983
# Training Observation #3170: Loss = 1.2846024
# Training Observation #3180: Loss = 0.010700937
# Training Observation #3190: Loss = 0.019584397
# Training Observation #3200: Loss = 5.873094
# Training Observation #3210: Loss = 0.12412857
# Training Observation #3220: Loss = 0.16991788
# Training Observation #3230: Loss = 0.03907534
# Training Observation #3240: Loss = 1.422238
# Training Observation #3250: Loss = 2.8449458e-05
# Training Observation #3260: Loss = 1.2795573
# Training Observation #3270: Loss = 0.0031306534
# Training Observation #3280: Loss = 9.083049
# Training Observation #3290: Loss = 0.010181658
# Training Observation #3300: Loss = 1.8581765
# Training Observation #3310: Loss = 0.00021149276
# Training Observation #3320: Loss = 0.0020861288
# Training Observation #3330: Loss = 2.5144587
# Training Observation #3340: Loss = 8.633535e-05
# Training Observation #3350: Loss = 0.44572523
# Training Observation #3360: Loss = 0.0046740347
# Training Observation #3370: Loss = 0.001796438
# Training Observation #3380: Loss = 0.009423167
# Training Observation #3390: Loss = 0.039916374
# Training Observation #3400: Loss = 0.0024164882
# Training Observation #3410: Loss = 0.005024699
# Training Observation #3420: Loss = 0.000109370754
# Training Observation #3430: Loss = 0.0010485584
# Training Observation #3440: Loss = 0.31483477
# Training Observation #3450: Loss = 0.0030382958
# Training Observation #3460: Loss = 0.0011105423
# Training Observation #3470: Loss = 0.0056330026
# Training Observation #3480: Loss = 0.00017068574
# Training Observation #3490: Loss = 4.797366
# Training Observation #3500: Loss = 0.00021696891
# Training Observation #3510: Loss = 0.0032425376
# Training Observation #3520: Loss = 0.23208082
# Training Observation #3530: Loss = 5.127238
# Training Observation #3540: Loss = 0.0042652846
# Training Observation #3550: Loss = 0.00086322514
# Training Observation #3560: Loss = 0.27358907
# Training Observation #3570: Loss = 0.00025503553
# Training Observation #3580: Loss = 2.6150079e-05
# Training Observation #3590: Loss = 5.107247e-05
# Training Observation #3600: Loss = 0.0037190577
# Training Observation #3610: Loss = 1.947958e-05
# Training Observation #3620: Loss = 0.0038354902
# Training Observation #3630: Loss = 0.00016647908
# Training Observation #3640: Loss = 0.0024977457
# Training Observation #3650: Loss = 0.71377534
# Training Observation #3660: Loss = 0.00056755164
# Training Observation #3670: Loss = 0.0003192016
# Training Observation #3680: Loss = 0.51606065
# Training Observation #3690: Loss = 0.051460717
# Training Observation #3700: Loss = 0.0032245973
# Training Observation #3710: Loss = 2.2522298e-05
# Training Observation #3720: Loss = 0.26654142
# Training Observation #3730: Loss = 0.006008787
# Training Observation #3740: Loss = 7.857169e-05
# Training Observation #3750: Loss = 0.010142727
# Training Observation #3760: Loss = 5.235235e-06
# Training Observation #3770: Loss = 0.02718012
# Training Observation #3780: Loss = 0.00011057321
# Training Observation #3790: Loss = 2.1991322e-05
# Training Observation #3800: Loss = 1.0015289e-05
# Training Observation #3810: Loss = 0.55567557
# Training Observation #3820: Loss = 0.027398562
# Training Observation #3830: Loss = 0.94119906
# Training Observation #3840: Loss = 0.0001939296
# Training Observation #3850: Loss = 3.8795108e-05
# Training Observation #3860: Loss = 0.06974881
# Training Observation #3870: Loss = 0.059776526
# Training Observation #3880: Loss = 0.00015399684
# Training Observation #3890: Loss = 0.0008798381
# Training Observation #3900: Loss = 6.9427606e-06
# Training Observation #3910: Loss = 1.9231586
# Training Observation #3920: Loss = 0.27108553
# Training Observation #3930: Loss = 1.6262505
# Training Observation #3940: Loss = 1.0967677
# Training Observation #3950: Loss = 0.00019602312
# Training Observation #3960: Loss = 0.35632437
# Training Observation #3970: Loss = 0.055163268
# Training Observation #3980: Loss = 0.0015429778
# Training Observation #3990: Loss = 9.278262e-07
# Training Observation #4000: Loss = 7.6848583
# Training Observation #4010: Loss = 6.8993893
# Training Observation #4020: Loss = 0.10336826
# Training Observation #4030: Loss = 6.455138e-05
# Training Observation #4040: Loss = 0.2498673
# Training Observation #4050: Loss = 4.680919
# Training Observation #4060: Loss = 0.00448252
# Training Observation #4070: Loss = 0.6099525
# Training Observation #4080: Loss = 0.052054025
# Training Observation #4090: Loss = 3.0371919
# Training Observation #4100: Loss = 0.00083054445
# Training Observation #4110: Loss = 3.3221746e-05
# Training Observation #4120: Loss = 1.7080476
# Training Observation #4130: Loss = 0.00042309263
# Training Observation #4140: Loss = 0.0009362357
# Training Observation #4150: Loss = 0.487926
# Training Observation #4160: Loss = 1.0094519
# Training Observation #4170: Loss = 0.00030666724
# Training Observation #4180: Loss = 2.9946656
# Training Observation #4190: Loss = 0.004622036
# Training Observation #4200: Loss = 0.00020401826
# Training Observation #4210: Loss = 2.3261899e-05
# Training Observation #4220: Loss = 5.4510394e-05
# Training Observation #4230: Loss = 1.0141661e-05
# Training Observation #4240: Loss = 0.00029411563
# Training Observation #4250: Loss = 0.0022212933
# Training Observation #4260: Loss = 8.3113664e-05
# Training Observation #4270: Loss = 0.00023010855
# Training Observation #4280: Loss = 2.2052472
# Training Observation #4290: Loss = 0.0008625457
# Training Observation #4300: Loss = 3.6100917
# Training Observation #4310: Loss = 0.0012142629
# Training Observation #4320: Loss = 3.2571766e-05
# Training Observation #4330: Loss = 7.2398354e-05
# Training Observation #4340: Loss = 1.5295533e-05
# Training Observation #4350: Loss = 0.00010980277
# Training Observation #4360: Loss = 6.309841e-07
# Training Observation #4370: Loss = 0.00082000496
# Training Observation #4380: Loss = 0.01975929
# Training Observation #4390: Loss = 0.00012642748
# Training Observation #4400: Loss = 3.379814e-05
# Training Observation #4410: Loss = 8.495827
# Training Observation #4420: Loss = 0.2329192
# Training Observation #4430: Loss = 6.7556376
# Training Observation #4440: Loss = 0.00021338907
# Training Observation #4450: Loss = 0.0035721702

# %%
print('Getting Test Set Accuracy For {} Sentences.'.format(len(texts_test)))
test_acc_all = []
for ix, t in enumerate(vocab_processor.fit_transform(texts_test)):
    y_data = [[target_test[ix]]]
    
    if (ix+1)%50==0:
        print('Test Observation #' + str(ix+1))    
    
    # Keep trailing average of past 50 observations accuracy
    # Get prediction of single observation
    [[temp_pred]] = sess.run(prediction, feed_dict={x_data:t, y_target:y_data})
    # Get True/False if prediction is accurate
    test_acc_temp = target_test[ix]==np.round(temp_pred)
    test_acc_all.append(test_acc_temp)

print('\nOverall Test Accuracy: {}'.format(np.mean(test_acc_all)))
# Out:
# Getting Test Set Accuracy For 1115 Sentences.
# Test Observation #50
# Test Observation #100
# Test Observation #150
# Test Observation #200
# Test Observation #250
# Test Observation #300
# Test Observation #350
# Test Observation #400
# Test Observation #450
# Test Observation #500
# Test Observation #550
# Test Observation #600
# Test Observation #650
# Test Observation #700
# Test Observation #750
# Test Observation #800
# Test Observation #850
# Test Observation #900
# Test Observation #950
# Test Observation #1000
# Test Observation #1050
# Test Observation #1100
#
# Overall Test Accuracy: 0.8269058295964126

# %%
# %matplotlib inline
# Plot training accuracy over time
plt.plot(range(len(train_acc_avg)), train_acc_avg, 'k-', label='Train Accuracy')
plt.title('Avg Training Acc Over Past 50 Iterations')
plt.xlabel('Iterations')
plt.ylabel('Training Accuracy')
plt.show()
